# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm

from sklearn.metrics import mean_squared_error, r2_score, accuracy_score

# %% [markdown]
# ## Task 1

# %%
# The training data
dfTrainData = pd.read_csv("./TrainData.csv")
dfTrainData
# Out:
#             TIMESTAMP     POWER       U10       V10      WS10      U100  \
# 0       20120101 1:00  0.273678  0.534894 -3.660243  3.699120  0.765355
# 1       20120101 2:00  0.086796  0.330813 -2.676430  2.696797  0.469875
# 2       20120101 3:00  0.006811 -0.065839 -2.029072  2.030140 -0.020893
# 3       20120101 4:00  0.018646 -0.419549 -1.799090  1.847362 -0.444867
# 4       20120101 5:00  0.034812 -0.754224 -1.661526  1.824698 -0.838274
# ...               ...       ...       ...       ...       ...       ...
# 16075  20131031 20:00  0.101254 -1.459917 -1.778960  2.301316 -1.974368
# 16076  20131031 21:00  0.105047 -1.293326 -2.350447  2.682777 -0.781394
# 16077  20131031 22:00  0.145079 -0.308284 -2.441885  2.461269  0.257905
# 16078  20131031 23:00  0.180933  1.148765 -2.789011  3.016330  1.628004
# 16079   20131101 0:00  0.236826  2.879322 -2.077827  3.550755  3.667186
#
#            V100     WS100
# 0     -4.486657  4.551468
# 1     -3.213752  3.247920
# ...

# %%
# Limit use of wind speed at 10m above ground level
dfTrainData = dfTrainData.drop(columns=['U100', 'V100', 'WS100'])
dfTrainData
# Out:
#             TIMESTAMP     POWER       U10       V10      WS10
# 0       20120101 1:00  0.273678  0.534894 -3.660243  3.699120
# 1       20120101 2:00  0.086796  0.330813 -2.676430  2.696797
# 2       20120101 3:00  0.006811 -0.065839 -2.029072  2.030140
# 3       20120101 4:00  0.018646 -0.419549 -1.799090  1.847362
# 4       20120101 5:00  0.034812 -0.754224 -1.661526  1.824698
# ...               ...       ...       ...       ...       ...
# 16075  20131031 20:00  0.101254 -1.459917 -1.778960  2.301316
# 16076  20131031 21:00  0.105047 -1.293326 -2.350447  2.682777
# 16077  20131031 22:00  0.145079 -0.308284 -2.441885  2.461269
# 16078  20131031 23:00  0.180933  1.148765 -2.789011  3.016330
# 16079   20131101 0:00  0.236826  2.879322 -2.077827  3.550755
#
# [16080 rows x 5 columns]

# %%
# apply machine learning techniques to find the relationship between wind power generation and wind speed
# apparently, each machine learning technique has a different training model.

# %%
""" Linear Regression """
dfLR = dfTrainData

# Separate features and target variable
x = dfLR.iloc[:, 2:]
y = dfLR.iloc[:, 1]

# Split dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Train the linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Prediction
y_pred = model.predict(X_test)

# Evaluation of the model
print('Coefficients:', model.coef_)
print('Intercept:', model.intercept_)
print('Mean squared error (MSE):', np.round(mean_squared_error(y_test, y_pred), 3))
print('Root mean squared error (RMSE):', np.round(np.sqrt(mean_squared_error(y_test, y_pred)), 3))

# save to ForecastTemplate1-LR.csv
# Out:
# Coefficients: [-0.00683487 -0.01629649  0.12788915]
# Intercept: -0.09763085627405876
# Mean squared error (MSE): 0.051
# Root mean squared error (RMSE): 0.225

# %%
""" K Nearest Neighbors (kNN) """
dfKNN = dfTrainData

# Split dataset into training and testing sets
dfKNN['WPGxWS'] = ""
X_train, X_test, y_train, y_test = train_test_split(dfKNN, dfKNN['WPGxWS'], test_size=0.2)

# Train the linear regression model
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)

# Prediction
y_pred = knn.predict(X_test)
print("Accuracy Score:", accuracy_score(y_test, y_pred))

# Evaluation of the model
print('Coefficients:', model.coef_)
print('Intercept:', model.intercept_)
print('Mean squared error (MSE):', np.round(mean_squared_error(y_test, y_pred), 3))
print('Root mean squared error (RMSE):', np.round(np.sqrt(mean_squared_error(y_test, y_pred)), 3))

# save to ForecastTemplate1-kNN.csv
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19900\3071458613.py in ?()
#       6 X_train, X_test, y_train, y_test = train_test_split(dfKNN, dfKNN['WPGxWS'], test_size=0.2)
#       7
#       8 # Train the linear regression model
#       9 knn = KNeighborsClassifier(n_neighbors=3)
# ---> 10 knn.fit(X_train, y_train)
#      11
#      12 # Prediction
#      13 y_pred = knn.predict(X_test)
#
# c:\Users\Dan28\anaconda3\Lib\site-packages\sklearn\neighbors\_classification.py in ?(self, X, y)
#     211             The fitted k-nearest neighbors classifier.
#     212         """
#     213         self._validate_params()
#     214
# --> 215         return self._fit(X, y)
#
# c:\Users\Dan28\anaconda3\Lib\site-packages\sklearn\neighbors\_base.py in ?(self, X, y)
#     451     def _fit(self, X, y=None):
#     452         if self._get_tags()["requires_y"]:
# ...

# %%
# Supported Vector Regression (SVR)

# save to ForecastTemplate1-SVR.csv

# %%
# Artificial Neural Networks (ANN)

# save to ForecastTemplate1-NN.csv

# %%
# Find the wind speed for the whole month of 11.2013 in WeatherForecastInput.csv
dfWFInput = pd.read_csv("./WeatherForecastInput.csv")
dfWFInput
# Out:
#           TIMESTAMP       U10       V10      WS10      U100       V100  \
# 0     20131101 1:00  3.462251 -1.066374  3.622753  4.323671  -1.330859
# 1     20131101 2:00  3.651341 -0.337717  3.666925  4.532444  -0.451426
# 2     20131101 3:00  3.657829  0.328049  3.672510  4.527268   0.341374
# 3     20131101 4:00  3.551698  0.735371  3.627028  4.395563   0.818799
# 4     20131101 5:00  3.586921  1.050811  3.737673  4.461128   1.251971
# ..              ...       ...       ...       ...       ...        ...
# 715  20131130 20:00 -2.527419 -6.623859  7.089666 -3.648235 -11.876879
# 716  20131130 21:00 -2.529020 -7.423845  7.842794 -3.553146 -12.504219
# 717  20131130 22:00 -3.105103 -6.653005  7.341943 -4.423704 -12.561661
# 718  20131130 23:00 -2.286417 -6.165074  6.575396 -2.957473  -9.009961
# 719   20131201 0:00  1.047175 -5.420364  5.520590  1.336842  -7.335118
#
#          WS100
# 0     4.523861
# 1     4.554870
# 2     4.540120
# 3     4.471175
# 4     4.633475
# ..         ...
# ...

# %%
# Evaluate the prediction accuracy
# Compare the predicted wind power and the true wind power measurements (in the file Solution.csv)
# Use the error metric RMSE to evaluate and compare the prediction accuracy among the machine learning approaches

df = pd.read_csv("./Solution.csv")
df
# Out:
#           TIMESTAMP     POWER
# 0     20131101 1:00  0.167215
# 1     20131101 2:00  0.063998
# 2     20131101 3:00  0.039035
# 3     20131101 4:00  0.036232
# 4     20131101 5:00  0.064888
# ..              ...       ...
# 715  20131130 20:00  0.963328
# 716  20131130 21:00  0.948834
# 717  20131130 22:00  0.925991
# 718  20131130 23:00  0.773840
# 719   20131201 0:00  0.152735
#
# [720 rows x 2 columns]

# %% [markdown]
# ## Task 2

# %%
# Calculate the wind direction based on the zonal component U10 and meridional component V10 in the file TrainData.csv

# %%
# Build a Multiple Linear Regression (MLR) model between wind power generation and two weather parameters (i.e., wind speed and wind direction)

# %%
# Predict the wind power production for the whole month 11.2013; based on the MLR model and weather data in WeatherForecastInput.csv

# %%
# The predicted wind power production is saved in the file ForecastTemplate2.csv
# Compare the predicted wind power and the true wind power measurements (in the file Solution.csv) by using the metric RMSE
# Compare the prediction accuracy with the linear regression where only wind speed is considered
